# %% [markdown]
# # Purpose

# %% [markdown]
# The goal of this project is to create a dashboard to display data from a dataset. First we need to clean our data, then we can display it. The dataset used can be found [here](https://www.kaggle.com/arashnic/hr-analytics-job-change-of-data-scientists). I'll be including the metadata for ease of use. Please note that I will only be using the training dataset, since my ultimate goal is not to predict data but to display it in a meaningful way. Also, I will be doing my best to maintain the accuracy of the data, but since there are many NaN rows, this may not be possible. It's not a big issue however, since my goal is only to display data, not analysis.

# %% [markdown]
# # Data Description

# %% [markdown]
# A company which is active in Big Data and Data Science wants to hire data scientists among people who successfully pass some courses which conduct by the company. Many people signup for their training. Company wants to know which of these candidates are really wants to work for the company after training or looking for a new employment because it helps to reduce the cost and time as well as the quality of training or planning the courses and categorization of candidates. Information related to demographics, education, experience are in hands from candidates signup and enrollment.
#
# This dataset designed to understand the factors that lead a person to leave current job for HR researches too. By model(s) that uses the current credentials,demographics,experience data you will predict the probability of a candidate to look for a new job or will work for the company, as well as interpreting affected factors on employee decision.
#
# The whole data divided to train and test . Target isn't included in test but the test target values data file is in hands for related tasks. A sample submission correspond to enrollee_id of test set provided too with columns : enrollee _id , target
#
# Note:
#
# The dataset is imbalanced.
# Most features are categorical (Nominal, Ordinal, Binary), some with high cardinality.
# Missing imputation can be a part of your pipeline as well.
# Features
#
# * enrollee_id : Unique ID for candidate
# * city: City code
# * city_ development _index : Developement index of the city (scaled)
# * gender: Gender of candidate
# * relevent_experience: Relevant experience of candidate
# * enrolled_university: Type of University course enrolled if any
# * education_level: Education level of candidate
# * major_discipline :Education major discipline of candidate
# * experience: Candidate total experience in years
# * company_size: No of employees in current employer's company
# * company_type : Type of current employer
# * lastnewjob: Difference in years between previous job and current job
# * training_hours: training hours completed
# * target: 0 – Not looking for job change, 1 – Looking for a job change

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
jobdata = pd.read_csv('aug_train.csv')
jobdata
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
# Checking nans for all columns
jobdata.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %% [markdown]
# Looks enrolee_id, city, city_development_index, relevent_experience, training_hours, and target have data values that are complete. First thing we need to do is deal with the columns that have nans, or we will have issues.

# %%
# Exploring the gender column
jobdata['gender'].value_counts(dropna=False)
# Out:
# Male      13221
# NaN        4508
# Female     1238
# Other       191
# Name: gender, dtype: int64

# %% [markdown]
# We will be changing the NaN gender values to No Reponse Given, since there are is a large amount of data with NaN values. It would eliminate too much data if we cut all those values out entirely, and since the goal of this project is simply to create a dashboard, the signifigance of having incorrect data will not affect our goal.

# %%
jobdata['gender'] = jobdata['gender'].fillna('No Response Given')

# %%
# Exploring the enrolled_university column
jobdata['enrolled_university'].value_counts(dropna=False)
# Out:
# no_enrollment       13817
# Full time course     3757
# Part time course     1198
# NaN                   386
# Name: enrolled_university, dtype: int64

# %% [markdown]
# It looks like most individuals are not currently enrolled in university courses. For that reason we will replace the NaN values with no_enrollement. Enrolling is also an optional choice as well, unlike gender which each individual must have, therefore it makes sense to replace NaN values with the most common value.

# %%
jobdata['enrolled_university'] = jobdata['enrolled_university'].fillna('no_enrollment')

# %%
# Exploring the education_level column
jobdata['education_level'].value_counts(dropna=False)
# Out:
# Graduate          11598
# Masters            4361
# High School        2017
# NaN                 460
# Phd                 414
# Primary School      308
# Name: education_level, dtype: int64

# %% [markdown]
# I had a feeling that having no education (an NaN value) would also mean that you would have no major_discipline as well.

# %%
test1 = jobdata['education_level'].fillna(1)

# %%
test2 = jobdata['major_discipline'].fillna(1)

# %%
test1.eq(test2).value_counts()
# Out:
# False    18698
# True       460
# dtype: int64

# %% [markdown]
# After some testing it looks like that assumption was correct. We can then replace the NaN values in education_level with "No Education" as they exactly correspond to the major_discipline NaN values. This makes sense since if you have no education, you cannot have a major_discipline. We also change the corresponding major_discipline as well.

# %%
jobdata['education_level'] = jobdata['education_level'].fillna('No Education')

# %%
# find where education_level == 'No education', and change the corresponding rows in major_discipline to 'No Major'
jobdata.loc[jobdata['education_level'] == 'No Education', 'major_discipline'] = 'No Major'

# %%
# Exploring major_discipline
jobdata['major_discipline'].value_counts(dropna=False)
# Out:
# STEM               14492
# NaN                 2353
# No Major             683
# Humanities           669
# Other                381
# Business Degree      327
# Arts                 253
# Name: major_discipline, dtype: int64

# %% [markdown]
# Using the same logic we change the major_discipline of 'High School' education_level and 'Primary School' to 'No Major' as well, since individuals with these education levels would have NaNs for major_discipline,.

# %%
# find where education_level == 'High School', and change the corresponding rows in major_discipline to 'No Major'
jobdata.loc[jobdata['education_level'] == 'High School', 'major_discipline'] = 'No Major'
# find where education_level == 'Primary School', and change the corresponding rows in major_discipline to 'No Major'
jobdata.loc[jobdata['education_level'] == 'Primary School', 'major_discipline'] = 'No Major'

# %%
jobdata['major_discipline'].value_counts(dropna=False)
# Out:
# STEM               14492
# No Major            3008
# Humanities           669
# Other                381
# Business Degree      327
# Arts                 253
# NaN                   28
# Name: major_discipline, dtype: int64

# %% [markdown]
# We have now chopped down our NaN values to just a mere 28. Now lets take a look at the remaining rows where major_discipine is NaN

# %%
jobdata.loc[jobdata['major_discipline'].isna()]
# Out:
#        enrollee_id      city  city_development_index             gender  \
# 391          12038   city_90                   0.698               Male
# 1771          1485  city_103                   0.920  No Response Given
# 3796          2946   city_21                   0.624  No Response Given
# 3923         22935  city_136                   0.897  No Response Given
# 4859         23075   city_16                   0.910               Male
# 5190         16615  city_162                   0.767  No Response Given
# 6405          2874   city_41                   0.827  No Response Given
# 7816         28855   city_16                   0.910               Male
# 8272         18836  city_136                   0.897  No Response Given
# 9038         17738   city_99                   0.915  No Response Given
# 10304         2901  city_104                   0.924               Male
# 12451        27534   city_41                   0.827               Male
# 12595        12551   city_21                   0.624  No Response Given
# 13091        13136  city_103                   0.920  No Response Given
# 13133         2493  city_136                   0.897               Male
# 13505        23349   city_50                   0.896               Male
# 15393        10798   city_73                   0.754  No Response Given
# 16546        32641   city_21                   0.624               Male
# 16564        24718   city_21                   0.624  No Response Given
# 16702        15873   city_13                   0.827               Male
# 17063         8967  city_165                   0.903  No Response Given
# 17259        31502   city_75                   0.939               Male
# 17696        21061  city_100                   0.887  No Response Given
# 18208        23136  city_103                   0.920  No Response Given
# 18227        25347   city_11                   0.550  No Response Given
# 18984        22528   city_21                   0.624  No Response Given
# 19013        17245   city_64                   0.666  No Response Given
# 19151        11385  city_149                   0.689               Male
#
#            relevent_experience enrolled_university education_level  \
# 391    Has relevent experience    Full time course         Masters
# 1771   Has relevent experience       no_enrollment        Graduate
# 3796    No relevent experience    Full time course        Graduate
# 3923    No relevent experience       no_enrollment        Graduate
# 4859   Has relevent experience       no_enrollment        Graduate
# 5190   Has relevent experience       no_enrollment        Graduate
# 6405   Has relevent experience    Part time course         Masters
# 7816   Has relevent experience       no_enrollment        Graduate
# 8272    No relevent experience    Full time course        Graduate
# 9038    No relevent experience    Full time course        Graduate
# 10304  Has relevent experience       no_enrollment        Graduate
# 12451  Has relevent experience       no_enrollment        Graduate
# 12595  Has relevent experience    Full time course        Graduate
# 13091   No relevent experience    Full time course        Graduate
# 13133  Has relevent experience       no_enrollment         Masters
# 13505  Has relevent experience       no_enrollment         Masters
# 15393  Has relevent experience       no_enrollment         Masters
# 16546   No relevent experience       no_enrollment        Graduate
# 16564   No relevent experience    Full time course        Graduate
# 16702  Has relevent experience       no_enrollment         Masters
# 17063  Has relevent experience    Full time course        Graduate
# 17259  Has relevent experience       no_enrollment        Graduate
# 17696   No relevent experience       no_enrollment        Graduate
# 18208   No relevent experience       no_enrollment        Graduate
# 18227   No relevent experience    Full time course        Graduate
# 18984  Has relevent experience       no_enrollment        Graduate
# 19013  Has relevent experience       no_enrollment        Graduate
# 19151   No relevent experience    Full time course        Graduate
#
#       major_discipline experience company_size   company_type last_new_job  \
# 391                NaN        NaN          NaN            NaN          NaN
# 1771               NaN         15        50-99        Pvt Ltd           >4
# 3796               NaN          2          NaN        Pvt Ltd            1
# 3923               NaN          3          NaN            NaN          NaN
# 4859               NaN        >20    1000-4999  Public Sector           >4
# 5190               NaN         16          NaN            NaN          NaN
# 6405               NaN         18       10000+        Pvt Ltd           >4
# 7816               NaN         10       10000+        Pvt Ltd            3
# 8272               NaN          3          NaN            NaN        never
# 9038               NaN          5          NaN            NaN            1
# 10304              NaN          6        50-99        Pvt Ltd            1
# 12451              NaN        >20        10/49        Pvt Ltd            3
# 12595              NaN          6       10000+        Pvt Ltd            1
# 13091              NaN          2          NaN            NaN            1
# 13133              NaN         10    1000-4999        Pvt Ltd            2
# 13505              NaN        >20    1000-4999  Public Sector            1
# 15393              NaN        NaN        50-99        Pvt Ltd          NaN
# 16546              NaN          3          NaN            NaN          NaN
# 16564              NaN          4          NaN            NaN        never
# 16702              NaN        >20        10/49        Pvt Ltd            4
# 17063              NaN          5        50-99        Pvt Ltd            2
# 17259              NaN        >20      100-500        Pvt Ltd            3
# 17696              NaN         <1          NaN            NaN        never
# 18208              NaN          5    1000-4999        Pvt Ltd           >4
# 18227              NaN         <1        50-99        Pvt Ltd            1
# 18984              NaN         16          NaN            NaN           >4
# 19013              NaN         10          <10        Pvt Ltd            2
# 19151              NaN          2          NaN            NaN            1
#
#        training_hours  target
# 391                44     1.0
# 1771               42     0.0
# 3796               50     1.0
# 3923               92     0.0
# 4859                7     0.0
# 5190               43     0.0
# 6405               49     1.0
# 7816               14     0.0
# 8272               37     0.0
# 9038               18     1.0
# 10304              12     0.0
# 12451              16     0.0
# 12595              82     1.0
# 13091             202     1.0
# 13133              52     0.0
# 13505             308     1.0
# 15393               5     0.0
# 16546             100     1.0
# 16564             125     0.0
# 16702              34     0.0
# 17063              77     1.0
# 17259              57     0.0
# 17696              56     1.0
# 18208              43     0.0
# 18227              46     0.0
# 18984              67     0.0
# 19013               6     0.0
# 19151              60     0.0

# %% [markdown]
# We change the rest to "other" just for ease of use.

# %%
jobdata['major_discipline'] = jobdata['major_discipline'].fillna('Other')

# %% [markdown]
# We have now cleaned up the 'education_level' column of our dataset.

# %%
# Exploring the experience column
jobdata['experience'].value_counts(dropna=False)
# Out:
# >20    3286
# 5      1430
# 4      1403
# 3      1354
# 6      1216
# 2      1127
# 7      1028
# 10      985
# 9       980
# 8       802
# 15      686
# 11      664
# 14      586
# 1       549
# <1      522
# 16      508
# 12      494
# 13      399
# 17      342
# 19      304
# 18      280
# 20      148
# NaN      65
# Name: experience, dtype: int64

# %% [markdown]
# Looks like there are only 65 NaN values. Lets take a look at them.

# %%
jobdata.loc[jobdata['experience'].isna()]
# Out:
#        enrollee_id      city  city_development_index             gender  \
# 135          23947  city_103                   0.920  No Response Given
# 391          12038   city_90                   0.698               Male
# 1589         17642  city_134                   0.698  No Response Given
# 2727         14965  city_103                   0.920  No Response Given
# 2859         24875  city_103                   0.920  No Response Given
# ...            ...       ...                     ...                ...
# 18039         9158   city_21                   0.624  No Response Given
# 18055        32626  city_150                   0.698              Other
# 18143         2299   city_21                   0.624  No Response Given
# 18790        21862  city_114                   0.926  No Response Given
# 19025        17077  city_134                   0.698  No Response Given
#
#            relevent_experience enrolled_university education_level  \
# 135     No relevent experience       no_enrollment             Phd
# 391    Has relevent experience    Full time course         Masters
# 1589    No relevent experience       no_enrollment    No Education
# 2727   Has relevent experience       no_enrollment         Masters
# 2859    No relevent experience    Full time course        Graduate
# ...                        ...                 ...             ...
# 18039  Has relevent experience       no_enrollment         Masters
# 18055  Has relevent experience       no_enrollment    No Education
# 18143  Has relevent experience       no_enrollment        Graduate
# 18790  Has relevent experience       no_enrollment        Graduate
# 19025   No relevent experience       no_enrollment    No Education
#
#       major_discipline experience company_size company_type last_new_job  \
# 135               STEM        NaN          NaN          NaN          NaN
# 391              Other        NaN          NaN          NaN          NaN
# 1589          No Major        NaN          NaN          NaN        never
# 2727              STEM        NaN          NaN          NaN          NaN
# 2859              STEM        NaN        10/49          NaN            1
# ...                ...        ...          ...          ...          ...
# 18039             STEM        NaN    5000-9999          NaN            1
# 18055         No Major        NaN        10/49          NaN            1
# 18143             STEM        NaN        10/49          NaN          NaN
# 18790             STEM        NaN        50-99          NGO            1
# 19025         No Major        NaN          NaN          NaN        never
#
#        training_hours  target
# 135                70     0.0
# 391                44     1.0
# 1589               33     0.0
# 2727               70     0.0
# 2859               41     1.0
# ...               ...     ...
# 18039              13     1.0
# 18055              51     1.0
# 18143             182     1.0
# 18790             138     0.0
# 19025             106     0.0
#
# [65 rows x 14 columns]

# %% [markdown]
# Logically, if an individual has NaN for company_size and company_type, than that would also mean they would have NaN for experience. We can use this inference to help fill out some NaN values in the experience column.

# %%
# find where company_size == NaN & company_type == NaN, and change the corresponding rows in experience to 0
jobdata.loc[pd.isna(jobdata['company_size']) & pd.isna(jobdata['company_type']), 'experience'] = 0

# %%
jobdata.loc[jobdata['experience'].isna()].head()
# Out:
#       enrollee_id      city  city_development_index             gender  \
# 2859        24875  city_103                   0.920  No Response Given
# 3086        19706   city_11                   0.550  No Response Given
# 3760        21042  city_103                   0.920  No Response Given
# 4003        16736  city_103                   0.920  No Response Given
# 4207         9306   city_67                   0.855               Male
#
#           relevent_experience enrolled_university education_level  \
# 2859   No relevent experience    Full time course        Graduate
# 3086  Has relevent experience    Full time course  Primary School
# 3760  Has relevent experience    Full time course        Graduate
# 4003   No relevent experience       no_enrollment         Masters
# 4207  Has relevent experience       no_enrollment         Masters
#
#      major_discipline experience company_size         company_type  \
# 2859             STEM        NaN        10/49                  NaN
# 3086         No Major        NaN          <10  Early Stage Startup
# 3760             STEM        NaN        50-99       Funded Startup
# 4003             STEM        NaN       10000+                  NaN
# 4207  Business Degree        NaN          NaN              Pvt Ltd
#
#      last_new_job  training_hours  target
# 2859            1              41     1.0
# 3086          NaN              62     1.0
# 3760           >4              24     0.0
# 4003          NaN             103     0.0
# 4207           >4              96     1.0

# %%
jobdata['experience'].value_counts(dropna=False)
# Out:
# 0      5360
# >20    2422
# 5      1007
# 6       908
# 4       902
# 3       816
# 10      799
# 9       768
# 7       757
# 2       630
# 8       623
# 15      571
# 11      527
# 14      488
# 16      413
# 12      403
# 13      327
# 1       299
# 17      271
# <1      253
# 19      242
# 18      219
# 20      108
# NaN      45
# Name: experience, dtype: int64

# %% [markdown]
# Now it doesn't seem possible to extrapolate any further information. We drop the remaining rows with experience == NaN

# %%
jobdata = jobdata[jobdata['experience'].notna()]

# %%
# Exploring company_size, company_type
jobdata['company_size'].value_counts(dropna=False)
# Out:
# NaN          5935
# 50-99        3078
# 100-500      2563
# 10000+       2011
# 10/49        1466
# 1000-4999    1323
# <10          1304
# 500-999       874
# 5000-9999     559
# Name: company_size, dtype: int64

# %%
jobdata['company_type'].value_counts(dropna=False)
# Out:
# Pvt Ltd                9796
# NaN                    6124
# Funded Startup          999
# Public Sector           953
# Early Stage Startup     601
# NGO                     519
# Other                   121
# Name: company_type, dtype: int64

# %% [markdown]
# At this point it can be observed that if an individual has never had a job, then they will neither have any company_size or company_type. Therefore, it can be assumed that if an individual has NaN values for company_size and company_type, they have never held a job before. We will then change the NaN values to 0, and None respectively

# %%
# find where company_size == NaN & company_type == NaN, and change the corresponding rows in company_size and company_type to 0 and None respectively
# Made a copy of jobdata, to aviod SettingWithCopy warning
jobdf = jobdata.copy()
jobdf.loc[pd.isna(jobdf['company_size']) & pd.isna(jobdf['company_type']),['company_size','company_type']] = '0','None'

# %%
jobdf
# Out:
#        enrollee_id      city  city_development_index             gender  \
# 0             8949  city_103                   0.920               Male
# 1            29725   city_40                   0.776               Male
# 2            11561   city_21                   0.624  No Response Given
# 3            33241  city_115                   0.789  No Response Given
# 4              666  city_162                   0.767               Male
# ...            ...       ...                     ...                ...
# 19153         7386  city_173                   0.878               Male
# 19154        31398  city_103                   0.920               Male
# 19155        24576  city_103                   0.920               Male
# 19156         5756   city_65                   0.802               Male
# 19157        23834   city_67                   0.855  No Response Given
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience       no_enrollment        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM          0            0            None            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          0            0            None        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities          0            0            None            1
# 19154             STEM          0            0            None            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156         No Major         <1      500-999         Pvt Ltd            2
# 19157         No Major          0            0            None            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19113 rows x 14 columns]

# %%
jobdf['company_type'].value_counts(dropna=False)
# Out:
# Pvt Ltd                9796
# None                   5360
# Funded Startup          999
# Public Sector           953
# NaN                     764
# Early Stage Startup     601
# NGO                     519
# Other                   121
# Name: company_type, dtype: int64

# %%
jobdf['company_size'].value_counts(dropna=False)
# Out:
# 0            5360
# 50-99        3078
# 100-500      2563
# 10000+       2011
# 10/49        1466
# 1000-4999    1323
# <10          1304
# 500-999       874
# NaN           575
# 5000-9999     559
# Name: company_size, dtype: int64

# %% [markdown]
# The NaNs have been cut down quite a bit. From here, we can drop the rest of the NaN row since it is not possible to extrapolate data further.

# %%
jobdf = jobdf[jobdf['company_type'].notna()]

# %%
jobdf = jobdf[jobdf['company_size'].notna()]

# %%
# Checking nans for all columns
jobdf.isna().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                      0
# relevent_experience         0
# enrolled_university         0
# education_level             0
# major_discipline            0
# experience                  0
# company_size                0
# company_type                0
# last_new_job              354
# training_hours              0
# target                      0
# dtype: int64

# %%
# Exploring last_new_job
jobdf['last_new_job'].value_counts(dropna=False)
# Out:
# 1        7433
# >4       3185
# 2        2742
# never    2110
# 4         985
# 3         965
# NaN       354
# Name: last_new_job, dtype: int64

# %%
# Veiwing rows with last_new_job NaN
jobdf.loc[jobdf['last_new_job'].isna()]
# Out:
#        enrollee_id      city  city_development_index             gender  \
# 58           13478   city_21                   0.624  No Response Given
# 64            9572   city_11                   0.550  No Response Given
# 90           19128   city_61                   0.913               Male
# 135          23947  city_103                   0.920  No Response Given
# 205           4478   city_11                   0.550  No Response Given
# ...            ...       ...                     ...                ...
# 18944         2678  city_104                   0.924  No Response Given
# 19043        17966  city_114                   0.926  No Response Given
# 19106        18131  city_100                   0.887               Male
# 19113        11622   city_19                   0.682  No Response Given
# 19139         5603   city_21                   0.624  No Response Given
#
#            relevent_experience enrolled_university education_level  \
# 58     Has relevent experience    Full time course        Graduate
# 64      No relevent experience    Full time course     High School
# 90      No relevent experience    Full time course        Graduate
# 135     No relevent experience       no_enrollment             Phd
# 205    Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 18944   No relevent experience       no_enrollment             Phd
# 19043   No relevent experience    Full time course     High School
# 19106   No relevent experience    Full time course         Masters
# 19113   No relevent experience    Full time course        Graduate
# 19139  Has relevent experience    Full time course        Graduate
#
#       major_discipline experience company_size    company_type last_new_job  \
# 58                STEM          2        10/49  Funded Startup          NaN
# 64            No Major          0            0            None          NaN
# 90                STEM          0            0            None          NaN
# 135               STEM          0            0            None          NaN
# 205               STEM          5        50-99         Pvt Ltd          NaN
# ...                ...        ...          ...             ...          ...
# 18944             STEM        >20        50-99         Pvt Ltd          NaN
# 19043         No Major          0            0            None          NaN
# 19106             STEM          6      100-500   Public Sector          NaN
# 19113             STEM          0            0            None          NaN
# 19139             STEM          0            0            None          NaN
#
#        training_hours  target
# 58                 32     1.0
# 64                 98     0.0
# 90                140     0.0
# 135                70     0.0
# 205                 7     1.0
# ...               ...     ...
# 18944              27     0.0
# 19043              20     0.0
# 19106               8     0.0
# 19113              53     0.0
# 19139              13     0.0
#
# [354 rows x 14 columns]

# %% [markdown]
# Similar to earlier, if an idividual did not have a job ever, then they would also not have a last_new_job. We will replace those last_new_job rows with the value "never".

# %%
# find where experience == '0', and change the corresponding rows in last_new_job to 'never'
jobdf.loc[jobdata['experience'] == 0, 'last_new_job'] = 'never'

# %%
jobdf.loc[jobdf['last_new_job'].isna()]
# Out:
#        enrollee_id      city  city_development_index             gender  \
# 58           13478   city_21                   0.624  No Response Given
# 205           4478   city_11                   0.550  No Response Given
# 575          24981   city_45                   0.890  No Response Given
# 902           1926  city_123                   0.738  No Response Given
# 909          12104   city_21                   0.624  No Response Given
# ...            ...       ...                     ...                ...
# 18648        27777   city_21                   0.624               Male
# 18772         7756   city_21                   0.624  No Response Given
# 18863        10381  city_103                   0.920  No Response Given
# 18944         2678  city_104                   0.924  No Response Given
# 19106        18131  city_100                   0.887               Male
#
#            relevent_experience enrolled_university education_level  \
# 58     Has relevent experience    Full time course        Graduate
# 205    Has relevent experience       no_enrollment        Graduate
# 575    Has relevent experience       no_enrollment        Graduate
# 902     No relevent experience       no_enrollment         Masters
# 909    Has relevent experience       no_enrollment        Graduate
# ...                        ...                 ...             ...
# 18648  Has relevent experience       no_enrollment        Graduate
# 18772  Has relevent experience       no_enrollment        Graduate
# 18863  Has relevent experience       no_enrollment        Graduate
# 18944   No relevent experience       no_enrollment             Phd
# 19106   No relevent experience    Full time course         Masters
#
#       major_discipline experience company_size         company_type  \
# 58                STEM          2        10/49       Funded Startup
# 205               STEM          5        50-99              Pvt Ltd
# 575               STEM          9        50-99              Pvt Ltd
# 902               STEM         15        50-99              Pvt Ltd
# 909               STEM          9    5000-9999              Pvt Ltd
# ...                ...        ...          ...                  ...
# 18648             STEM          4       10000+              Pvt Ltd
# 18772             STEM          2          <10  Early Stage Startup
# 18863       Humanities         19       10000+              Pvt Ltd
# 18944             STEM        >20        50-99              Pvt Ltd
# 19106             STEM          6      100-500        Public Sector
#
#       last_new_job  training_hours  target
# 58             NaN              32     1.0
# 205            NaN               7     1.0
# 575            NaN              62     0.0
# 902            NaN              44     0.0
# 909            NaN              14     0.0
# ...            ...             ...     ...
# 18648          NaN              82     1.0
# 18772          NaN               4     0.0
# 18863          NaN              13     1.0
# 18944          NaN              27     0.0
# 19106          NaN               8     0.0
#
# [161 rows x 14 columns]

# %% [markdown]
# The remaining rows appear to be individuals who have never left thier current position and is in thier first job at the moment. They can also be classified as never having a last new job as well.

# %%
jobdf['last_new_job'] = jobdf['last_new_job'].fillna('never')

# %% [markdown]
# # Conclusion

# %% [markdown]
# With that, let's take a look at our cleaned data.

# %%
# Checking nans for all columns
jobdf.isna().sum()
# Out:
# enrollee_id               0
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# training_hours            0
# target                    0
# dtype: int64

# %% [markdown]
# There are no longer any NaN values in any of the columns. Please note that this was a very basic data cleaning opertaion. I would **NOT** clean data like this if my intent was to perform and analysis on the dataset. If I wanted to do an analysis, I would integrate NaN values that I could not logically determine into my analysis pipline instead. However, since the purpose of this project is to create a functional dashboard to display data, it doesn't matter too much.

# %%
# Export dataframe to csv
jobdf.to_csv('cleaneddata.csv')
